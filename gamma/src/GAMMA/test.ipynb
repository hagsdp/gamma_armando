# %%
import pandas as pd
import matplotlib.pyplot as plt
# import ipython

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["L1"], df["L2"], df["Avg_thrpt"], c="r", marker="o")
ax.set_xlabel('L1')
ax.set_ylabel('L2')
ax.set_zlabel('L3')
plt.show()
# Out:
# <div id='5cb63a97-7bb9-4661-8815-67abcb8afb4b'></div>

# %%
# %matplotlib widget
df = pd.read_csv("all_results")
columns = ["L1", "L2", "Avg_thrpt", "PEs"]
df = df[columns]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df["L1"], df["L2"], df["PEs"], marker="o", c=df["Avg_thrpt"], cmap=plt.cm.viridis) #df["Avg_thrpt"]
plt.colorbar(sc, ax=ax, label='Avg_thrpt')
ax.set_xlabel('L1')
ax.set_ylabel('L2')
ax.set_zlabel('PEs')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df["L1"].min(), df["L2"].min(), df["PEs"].min()
# Out:
# (np.float64(16.0), np.float64(128.0), np.float64(4.0))
